# %% [markdown]
# # Linear Vs. Non-Linear Functions

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Linear Functions

# %% [markdown]
# A linear function has the geometric interpretation as a line when we plot the space of inputs against the space of output. In one dimension, we simply have a constant value. It doesn't really make sense to speak of a function in terms of a singular dimension-- there is not input or output deliniation. In two dimensions, in the cartesian plane, we can plot values of x against values of y via y = f(x). In three dimensions, in 3d space, we can do a similar thing z = f(x,y).

# %%
# There are no functions in one dimension since we cannot deliniate inputs/outputs. 
# A single dimension is just a constant value of existence with no notion of difference. 

# Two dimensional funciton
def f2(x):
    return x

# Three dimensional funciton. Output is z.
def f3(x,y):
    return x + y

# Four dimensional function. We cannot visualize this easily. 
def f4(x,y,z):
    return x + y + z

t1 = np.arange(0.0, 5.0, 0.1)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f2(t1))

plt.subplot(212,projection="3d")
plt.plot(t1,t1, f3(t1,t1))
plt.show()

# %% [markdown]
# **Remark:** The derivitive of every linear function is a constant.

# %%
x_sym, y_sym = sp.symbols('x y')
print("dy/dx f2 = {0}".format(sp.diff(f2(x_sym))))
print("∂z/∂x f3 = {0}".format(sp.diff(f3(x_sym,y_sym),x_sym)))
# Out:
# dy/dx f2 = 1
# ∂z/∂x f3 = 1

# %% [markdown]
# **Definition:** A *linear combination* of varibles (x<sub>1</sub>, x<sub>2</sub>, ... , x<sub>n</sub>) = ∂<sub>1</sub>x<sub>1</sub> + ∂<sub>2</sub>x<sub>2</sub>+ ...</sub> + ∂<sub>n</sub>x<sub>n</sub> where ∂ are constants.
#
# **Remark:** All linear functions can be represented as a linear combination.

# %% [markdown]
# ## Non-Linear Functions

# %% [markdown]
# Non-linear functions are more unpredictable than linear functions because the derivitive of a non-linear function is always a function, not a constant. The geometric interpretation of non-linear functions encompasses the space diverse space of curves.

# %%
# Two dimensional funciton
def f2(x):
    return x**2

# Three dimensional funciton. Output is z.
def f3(x,y):
    return x * y

t1 = np.arange(0.0, 5.0, 0.1)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f2(t1))

plt.subplot(212,projection="3d")
plt.plot(t1,t1, f3(t1,t1))
plt.show()

# %% [markdown]
# **Remark:** The derivitive of every non-linear function is **not a constant**.

# %%
x_sym, y_sym = sp.symbols('x y')
print("dy/dx f2 = {0}".format(sp.diff(f2(x_sym))))
print("∂z/∂x f3 = {0}".format(sp.diff(f3(x_sym,y_sym),x_sym)))
# Out:
# dy/dx f2 = 2*x
# ∂z/∂x f3 = y

# %% [markdown]
# **Remark:** Non-linear functions cannot be represented by a linear combination.
